# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
#read the 2017-2018 data and put it into a df
last_year = "PGATOUR_data2017.csv"
lastseason_df = pd.read_csv(last_year)
lastseason_df.dropna()
# Out:
#                  Player  EVENTS_PLAYED  POINTS  NUMBER_OF_WINS  \
# 0        Aaron Baddeley           27.0   342.0             0.0
# 1            Aaron Wise           27.0  1498.0             1.0
# 2         Abraham Ancer           29.0   909.0             0.0
# 3           Adam Hadwin           24.0  1054.0             0.0
# 4           Adam Schenk           28.0   239.0             0.0
# 5            Adam Scott           20.0  1052.0             0.0
# 6            Alex Cejka           24.0   524.0             0.0
# 7            Alex Noren           17.0  1033.0             0.0
# 8         Andrew Landry           26.0  1145.0             1.0
# 9         Andrew Putnam           27.0  1063.0             1.0
# 10           Andrew Yun           22.0    16.0             0.0
# 11       Anirban Lahiri           24.0   566.0             0.0
# 12          Austin Cook           28.0  1094.0             1.0
# 13         Beau Hossler           27.0  1043.0             0.0
# ...

# %%
#read the 2018-2019 data and put it into a df
this_year = "This_Season_Clean_data.csv"
thisseason_df = pd.read_csv(this_year)
thisseason_df.head()
# Out:
#    Unnamed: 0     Player Name  AVG_Driving_Distance  FAIRWAY_HIT_%  \
# 0           0  Aaron Baddeley               286.300         326.00
# 1           1      Aaron Pike                   NaN            NaN
# 2           2       Aaron Rai                   NaN            NaN
# 3           3      Aaron Wise               303.750         411.75
# 4           4   Abraham Ancer               292.975         555.50
#
#    AVG_CARRY_DISTANCE  AVG_SCORE  WORLD_RANK
# 0               273.8  71.110000      0.8675
# 1                 NaN        NaN      0.2300
# 2                 NaN        NaN      0.9750
# 3               288.0  70.893333      1.9125
# 4               269.9  70.646667      2.1400
